# %%
clean_up_steps = [0,5000,10000,15000,20000,25000,30000,35000,40000,45000,50000]
SoRB_success = {}
SoRB_success[5] = [0,0,0.10,0.20, 0.10, 0.15, 0.35, 0.25, 0.25, 0.15,0.25]
SoRB_success[4] = [0,0,0.15,0,0.05, 0.05, 0.05, 0.15, 0.10,0.10,0.05]
SoRB_success[3] = [0.05,0,0.20,0.30,0.25, 0.15, 0.10, 0.10, 0.25,0.20,0.20]
SoRB_success[2] = [0.10,0.20,0.45,0.20,0.25, 0.25, 0.40, 0.35, 0.40,0.20,0.20]
SoRB_success[1] = [0.45,0.30,0.30,0.20,0.10, 0.15, 0.10, 0.15, 0.20,0.0,0.0]


import matplotlib.pyplot as plt
  
f = plt.figure()
f.set_figwidth(8)
f.set_figheight(5)

  
# plot lines
plt.plot(clean_up_steps, SoRB_success[1], label = "Wall Thickness 1")
plt.plot(clean_up_steps, SoRB_success[2], label = "Wall Thickness 3")
plt.plot(clean_up_steps, SoRB_success[3], label = "Wall Thickness 5")
plt.plot(clean_up_steps, SoRB_success[4], label = "Wall Thickness 7")
plt.plot(clean_up_steps, SoRB_success[5], label = "Wall Thickness 9")
plt.legend()
plt.xlabel('Cleanup Steps') 
plt.ylabel('Success Rate') 
  
# displaying the title
plt.title("SoRB Success Rate Over Cleanup Steps")
plt.show()

# %%
clean_up_steps = [0,5000,10000,15000,20000,25000,30000,35000,40000,45000,50000]
SGM_success = {}
SGM_success[5] = [0,0.05,0.45,0.70,0.45,0.20,0.60,0.80,0.70,0.75,0.80]
SGM_success[4] = [0,0.65,0.85,0.75,1,0.95,1,1,1,0.90,1]
SGM_success[3] = [0,0.45,0.95,0.80,1,1,1,0.95,0.95,1,1]
SGM_success[2] = [0.25,0.80,0.90,1,1,1,1,1,1,1,1]
SGM_success[1] = [0.95,0.65,0.40,0.25,0.10,0.3,0.35,0.10,0.10,0.05,0.15]


import matplotlib.pyplot as plt
  
f = plt.figure()
f.set_figwidth(8)
f.set_figheight(5)

  
# plot lines
plt.plot(clean_up_steps, SGM_success[1], label = "Wall Thickness 1")
plt.plot(clean_up_steps, SGM_success[2], label = "Wall Thickness 3")
plt.plot(clean_up_steps, SGM_success[3], label = "Wall Thickness 5")
plt.plot(clean_up_steps, SGM_success[4], label = "Wall Thickness 7")
plt.plot(clean_up_steps, SGM_success[5], label = "Wall Thickness 9")
plt.legend()
plt.xlabel('Cleanup Steps') 
plt.ylabel('Success Rate') 
  
# displaying the title
plt.title("SoRB+SGM Success Rate Over Cleanup Steps")
plt.show()

# %%
# Performance over thinness
thickness = [1,3,5,7,9]
SoRB_perf = [max(SoRB_success[1]),max(SoRB_success[2]),max(SoRB_success[3]),max(SoRB_success[4]),max(SoRB_success[5]) ]
SGM_perf = [max(SGM_success[1]),max(SGM_success[2]),max(SGM_success[3]),max(SGM_success[4]),max(SGM_success[5]) ]

plt.plot(thickness, SoRB_perf, label = "SoRB")
plt.plot(thickness, SGM_perf, label = "SoRB+SGM")

plt.legend()
plt.xlabel('Thickness') 
plt.ylabel('Success Rate') 
  
# displaying the title
plt.title("SoRB vs SoRB+SGM Success Rate over Thickness")
plt.show()

# %%
# 1
After filtering and 0 cleanup steps, SGM has success rate 0.95
After filtering and 5000 cleanup steps, SGM has success rate 0.65
After filtering and 10000 cleanup steps, SGM has success rate 0.40
After filtering and 15000 cleanup steps, SGM has success rate 0.25
After filtering and 20000 cleanup steps, SGM has success rate 0.10
After filtering and 25000 cleanup steps, SGM has success rate 0.30
After filtering and 30000 cleanup steps, SGM has success rate 0.35
After filtering and 35000 cleanup steps, SGM has success rate 0.10
After filtering and 40000 cleanup steps, SGM has success rate 0.10
After filtering and 45000 cleanup steps, SGM has success rate 0.05
[0.95,0.65,0.40,0.25,0.10,0.3,0.35,0.10,0.10,0.05,-1]

# %%
# 4
[0,0.65,0.85,0.75,1,0.95,1,1,1,0.90,1]
After filtering and 0 cleanup steps, SGM has success rate 0.00
After filtering and 5000 cleanup steps, SGM has success rate 0.65
After filtering and 10000 cleanup steps, SGM has success rate 0.85
After filtering and 15000 cleanup steps, SGM has success rate 0.75
After filtering and 25000 cleanup steps, SGM has success rate 1.00
After filtering and 0 cleanup steps, SGM has success rate 0.95
After filtering and 5000 cleanup steps, SGM has success rate 1.00
After filtering and 10000 cleanup steps, SGM has success rate 1.00
After filtering and 15000 cleanup steps, SGM has success rate 1.00
After filtering and 20000 cleanup steps, SGM has success rate 0.90



After filtering and 25000 cleanup steps, SGM has success rate 1.00
Took 5000 cleanup steps and evaluated SGM success rate in 691.23 seconds
After filtering and 30000 cleanup steps, SGM has success rate 1.00
Took 5000 cleanup steps and evaluated SGM success rate in 642.66 seconds
After filtering and 35000 cleanup steps, SGM has success rate 1.00
Took 5000 cleanup steps and evaluated SGM success rate in 628.11 seconds
After filtering and 40000 cleanup steps, SGM has success rate 1.00
Took 5000 cleanup steps and evaluated SGM success rate in 650.08 seconds
After filtering and 45000 cleanup steps, SGM has success rate 1.00
Took 5000 cleanup steps and evaluated SGM success rate in 638.82 seconds
After filtering and 50000 cleanup steps, SGM has success rate 0.95

# %%
#5
After filtering and 0 cleanup steps, SGM has success rate 0.00
After filtering and 5000 cleanup steps, SGM has success rate 0.05
After filtering and 10000 cleanup steps, SGM has success rate 0.45
After filtering and 15000 cleanup steps, SGM has success rate 0.70
After filtering and 20000 cleanup steps, SGM has success rate 0.45
After filtering and 25000 cleanup steps, SGM has success rate 0.20
After filtering and 30000 cleanup steps, SGM has success rate 0.60
After filtering and 35000 cleanup steps, SGM has success rate 0.80
After filtering and 40000 cleanup steps, SGM has success rate 0.70
After filtering and 45000 cleanup steps, SGM has success rate 0.75
0,0.05,0.45,0.70,0.45,0.20,0.60,0.80,0.70,0.75
